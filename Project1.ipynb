# %% [markdown]
# <a href="https://colab.research.google.com/github/jcowart1987/SalesPredictions/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is the name of the project *bold*

# %% [markdown]
# #Project 1: Part 1
# - Jon Cowart

# %% [markdown]
# ##Loading Data

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# ##Exploratory Visuals

# %% [markdown]
# ##Explanatory Visuals
